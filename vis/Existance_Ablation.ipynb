# %%
import matplotlib.pyplot as plt
import numpy as np
import math

font_mid = 12
font_small = 10
font_board = 1.5
lw = 3

# %%
lw = 2
lw2 = 2.5
x = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

RN18_Cf10_SKN = [37.59,43.96,45.81,46.67,47,47.2,47.71,46.74,45.73,38.5]
RN18_Cf10_KN = [35.36,41.5,42.87,43.53,45.17,45.51,45.14,45.16,43.01,30.77]

RN18_Cf10_XN = [35.07,41.64,43.13,44.58,45.12,44.89,45.64,45.04,42.94,31.37]
RN18_Cf10_KU = [36.71,42,44.33,45.11,45.81,46.01,45.88,45.82,43.72,32.11]

benchRN18_Cf10_Rob = [50.19,50.19,50.19,50.19,50.19,50.19,50.19,50.19,50.19,50.19]

fig, ax1 = plt.subplots(figsize=(6, 4))
# plt.title(r"$\bf{ResNet18 \ on \ Cifar10 \ Init \ Comparision}$", fontsize = 16)
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust \ Accuracy  \ (\%)}$", fontsize = 16)


ax1.plot(x, RN18_Cf10_SKN, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{Signed \ Kaiming \ Constant}$", lw=lw2)
ax1.plot(x, RN18_Cf10_KN, c='tab:blue', marker='*', markersize=3*lw, label=r"$\bf{Kaiming \ Normal}$", lw=lw2)

ax1.plot(x, RN18_Cf10_XN, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Xavier \ Normal}$", lw=lw2)
ax1.plot(x, RN18_Cf10_KU, c='tab:orange', marker='8', markersize=3*lw, label=r"$\bf{Kaiming \ Uniform}$", lw=lw2)

ax1.plot(x, benchRN18_Cf10_Rob, c='tab:purple', markersize=3*lw, lw=lw, linestyle="--")


ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

yticks = np.arange(30, 52, 3)
ax1.set_yticks(yticks)

leg = ax1.legend(fontsize=font_mid, loc='lower center', prop={'size': 14}, bbox_to_anchor=(0.42, 0))
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar10@Rob@Init.svg")

# %%
lw = 2
lw2 = 2.5
x = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

RN18_Cf100_SKN = [15.8,22.18,24.66,24.89,26.15,26.21,26.16,25.97,25.03,17.48]
RN18_Cf100_KN = [14.61,20.58,21.79,22.78,23.34,23.9,24.32,23.84,22.6,12.68]

RN18_Cf100_XN = [14.08,20.81,22.36,22.86,24.12,24.3,23.87,23.62,22.54,12.97]
RN18_Cf100_KU = [14.37,20.95,23.3,24.37,24.46,24.96,24.62,24.28,23.42,13.58]

benchRN18_Cf100_Rob = [26.94,26.94,26.94,26.94,26.94,26.94,26.94,26.94,26.94,26.94]

fig, ax1 = plt.subplots(figsize=(6,4))
# plt.title(r"$\bf{ResNet18 \ on \ Cifar10 \ Init \ Comparision}$", fontsize = 16)
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)


ax1.plot(x, RN18_Cf100_SKN, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{Signed \ Kaiming \ Constant}$", lw=lw2)
ax1.plot(x, RN18_Cf100_KN, c='tab:blue', marker='*', markersize=3*lw, label=r"$\bf{Kaiming \ Normal}$", lw=lw2)

ax1.plot(x, RN18_Cf100_XN, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Xavier \ Normal}$", lw=lw2)
ax1.plot(x, RN18_Cf100_KU, c='tab:orange', marker='8', markersize=3*lw, label=r"$\bf{Kaiming \ Uniform}$", lw=lw2)

ax1.plot(x, benchRN18_Cf100_Rob, c='tab:purple', markersize=3*lw, lw=lw, linestyle="--")


ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

leg = ax1.legend(fontsize=font_mid, loc='lower center', prop={'size': 14}, bbox_to_anchor=(0.42, 0))
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar100@Rob@Init.svg")

# %%
lw = 2
lw2 = 2.5
x = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

RN18_Cf10_EW = [37.59,43.96,45.81,46.67,47,47.2,47.71,46.74,45.73,38.5]
RN18_Cf10_RW = [29.97,36.33,39.19,41.1,42.28,43.64,43.55,43.14,40.25,29.39]
RN18_Cf10_KW = [17.16,30.38,27.29,32.93,35.46,37.54,37.57,37.68,25.14,24.36]

fig, ax1 = plt.subplots(figsize=(6,4))
# plt.title(r"$\bf{ResNet18 \ on \ Cifar10 \ Init \ Comparision}$", fontsize = 16)
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)


ax1.plot(x, RN18_Cf10_EW, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{Element\_wise}$", lw=lw2)
ax1.plot(x, RN18_Cf10_RW, c='tab:blue', marker='*', markersize=3*lw, label=r"$\bf{Row\_wise}$", lw=lw2)
ax1.plot(x, RN18_Cf10_KW, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Kernel\_wise}$", lw=lw2)

ax1.plot(x, benchRN18_Cf10_Rob, c='tab:purple', markersize=3*lw, lw=lw, linestyle="--")

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

leg = ax1.legend(fontsize=font_mid, loc='lower center', prop={'size': 16}, bbox_to_anchor=(0.36, 0))
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar10@Rob@Prune.svg")

# %%
lw = 2
lw2 = 2.5
x = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

RN18_Cf10_FGSM = [36.08,42.96,44.35,44.91,46.11,45.99,45.31,45.06,43.84,38.24]
RN18_Cf10_FGSMRS = [35.84,41.5,44.02,44.22,43.95,43.54,44.21,43.01,42.52,35.69]
RN18_Cf10_PGD7 = [37.59,43.96,45.81,46.67,47,47.2,47.71,46.74,45.73,38.5]

fig, ax1 = plt.subplots(figsize=(6,4))
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x, RN18_Cf10_PGD7, c='tab:red', marker='^', markersize=3*lw, label=r"$\bf{PGD}$", lw=lw2)
ax1.plot(x, RN18_Cf10_FGSM, c='tab:blue', marker='s', markersize=3*lw, label=r"$\bf{FGSM}$", lw=lw2)
ax1.plot(x, RN18_Cf10_FGSMRS, c='tab:green', marker='*', markersize=3*lw, label=r"$\bf{FGSM\_RS}$", lw=lw2)

ax1.plot(x, benchRN18_Cf10_Rob, c='tab:purple', markersize=3*lw, lw=lw, linestyle="--")

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

leg = ax1.legend(fontsize=font_mid, loc='best', prop={'size': 16})
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
ax1.grid(True)
plt.savefig("ResNet18@Cifar10@Rob@Adv.svg")
