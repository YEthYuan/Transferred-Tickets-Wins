# %%
import matplotlib.pyplot as plt
import numpy as np
import math

font_mid = 12
font_small = 10
font_board = 3
lw = 3

# %%
lw = 1.5
rst = [37.59,43.96,45.81,46.97,47,47.2,47.71,46.74,45.73,38.5]
ft_inher = [35.36,41.5,42.87,43.53,45.17,45.51,45.14,45.16,43.01,30.77]
ft_reinit = [35.07,41.64,43.13,44.58,45.12,44.89,45.64,45.04,42.94,31.37]
test = [36.71,42,44.33,45.11,45.81,46.01,45.88,45.82,43.72,32.11]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

fig, ax1 = plt.subplots()
plt.title(r"$\bf{ResNet18 \ on \ Cifar10 \ Init \ Comparision}$", fontsize = 16)
# ax1.set_xlabel(r"$\bf{Pruing Ratio (Remain)}$", fontsize = 16)
# ax1.set_ylabel(r"$\bf{Accuracy}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{ft\_inherit}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{ft\_reinit}$", lw=lw)
ax1.plot(x_overall, test, c='tab:orange', marker='*', markersize=3*lw, label=r"$\bf{ft\_init}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax1.set_ylim([67, 78])
# ax1.set_xlim([-0.5,4.5])

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='lower center')
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='y', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar10@InitComp.svg")

# %%
lw = 3
x_small = [0.01,0.03,0.05,0.07,0.1,0.15,0.2]
rst_small = [37.59,43.96,45.81,46.97,47,47.2,47.71]
ft_inher_small = [35.36,41.5,42.87,43.53,45.17,45.51,45.14]
ft_reinit_small = [35.07,41.64,43.13,44.58,45.12,44.89,45.64]
test = [36.71,42,44.33,45.11,45.81,46.01,45.88]

fig, ax1 = plt.subplots()
plt.title(r"$\bf{ResNet18 \ on \ Cifar10 \ Init \ Comparision}$", fontsize = 16)
ax1.plot(x_small, rst_small, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST}$", lw=lw)
ax1.plot(x_small, ft_inher_small, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{ft\_inherit}$", lw=lw)
ax1.plot(x_small, ft_reinit_small, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{ft\_reinit}$", lw=lw)
ax1.plot(x_small, test, c='tab:orange', marker='*', markersize=3*lw, label=r"$\bf{ft\_init}$", lw=lw)

ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax1.set_ylim([35, 50])
xticks = np.arange(0, 0.21, 0.05)
ax1.set_xticks(xticks)
ax1.set_xlim([0, 0.21])
# yticks = np.arange(35, 51, 2)
ax1.set_ylim([34, 49])
# ax1.set_yticks(yticks)

font_board = 2
ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='lower left')
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
ax1.grid(True)
plt.savefig("ResNet18@Cifar10@InitComp_sub.svg")
