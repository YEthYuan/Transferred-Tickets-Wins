# %%
import matplotlib.pyplot as plt
import numpy as np
import math

font_mid = 12
font_small = 10
font_board = 3
lw = 3


fname1="fps_acc.svg"
# x=[853,799,801,821,900]
# # y=[1/2693036*200e6,1/1962220*200e6,1/785772*200e6,1/672479*200e6,1/407546*200e6]
# # acc=[75.95,77.24, 76.98,76.22,76.45]
# lsf=6/8


# #*fbnetv2-f4,
# baselines = ["proxylessnass", "efficientnet", "fbnet-c",  "edd", "apq", "mp-nas-big", "mp-nas-small"]
# y=[48.02,36.34,38.60,40.2,25.3,70.65,106]


# # acc=[77.34 77.4  77.44 77.46 77.75]
# # acc=[77.34,77.4,77.44,77.46,77.75]
# #proxylessnass, efficientnet, fbnet-c, edd, apq-4, apq-1,mp-nas-big,mp-nas-small
# acc=[74.2,76.3,74.9,74.4,75.1,71.72,68.38]


# our_co_design_x=[803,768]
# our_co_design_fps=[61.69*lsf,85.08*lsf,93.06*lsf,110.08*lsf,146.67*lsf]
# our_co_design_acc=[76.2,75.7,74.9,73.9,72.2]


# for i in range(len(y)):
#     print('Baseline {:15} - acc: {}, fps: {:.2f}'.format(baselines[i], acc[i], y[i]))


# for i in range(len(our_co_design_acc)):
#     print('Ours - acc: {}, fps: {:.2f}'.format(our_co_design_acc[i], our_co_design_fps[i]))


ours_fps = [356.73, 240.9, 206.2, 153.84, 128.79]
ours_acc = [72.35, 73.23, 75.26, 76.13, 77.12]


homo_fps = [320.5, 238.2, 212.5, 148.7, 83.66]
homo_acc = [70.8, 72.1, 74.4, 75.6, 76.5]


seq_fps = [203.9, 178.53, 169.7, 93.31, 77.34]
seq_acc = [70.4, 71.3, 74.1, 76.5, 77.1]


fig, ax1 = plt.subplots()


# ax1.scatter(y[0], acc[0], s=120, facecolors='blue',edgecolors='blue',marker="s")
# ax1.scatter(y[1], acc[1], s=120, facecolors='g',edgecolors='g',marker="p")
# ax1.scatter(y[2], acc[2], s=120, facecolors='c',edgecolors='c',marker="P")
# ax1.scatter(y[3], acc[3], s=120, facecolors='m',edgecolors='m',marker="D")
# ax1.scatter(y[4], acc[4], s=120, facecolors='navy',edgecolors='navy',marker="h")
# ax1.scatter(y[5], acc[5], s=120, facecolors='orange',edgecolors='orange',marker="o")
# ax1.scatter(y[6], acc[6], s=120, facecolors='olivedrab',edgecolors='olivedrab',marker="v")


# ax1.tick_params(axis='y')
# ax1.scatter(our_co_design_fps[1],our_co_design_acc[1],s=150, facecolors='none', edgecolors='red',linewidths=2,marker="*")
# ax1.scatter(our_co_design_fps[0],our_co_design_acc[0],s=150, facecolors='none', edgecolors='red',linewidths=2,marker="*")
# ax1.scatter(our_co_design_fps[2],our_co_design_acc[2],s=150, facecolors='none', edgecolors='red',linewidths=2,marker="*")
# ax1.scatter(our_co_design_fps[3],our_co_design_acc[3],s=150, facecolors='none', edgecolors='red',linewidths=2,marker="*")
# ax1.scatter(our_co_design_fps[4],our_co_design_acc[4],s=150, facecolors='none', edgecolors='red',linewidths=2,marker="*")
# ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)


ax1.plot(ours_fps, ours_acc, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{TRIPS}$", lw=lw)
ax1.plot(homo_fps, homo_acc, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{TRIPS\ w/o\ h-sampling}$", lw=lw)
ax1.plot(seq_fps, seq_acc, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{Sequential\ Opt.}$", lw=lw)


ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)
ax1.set_ylim([67, 78])
# ax1.set_xlim([-0.5,4.5])


ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')


leg = ax1.legend(fontsize=font_mid, loc='lower left')
leg.get_frame().set_edgecolor("black")
leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
ax1.grid(True)
plt.savefig(fname1)
