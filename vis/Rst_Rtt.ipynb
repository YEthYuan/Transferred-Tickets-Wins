# %%
import matplotlib.pyplot as plt
import numpy as np
import math

font_mid = 12
font_small = 10
font_board = 1.5
lw = 3

# %%
font_board = 1.5
lw = 2
rst = [37.59,43.96,45.81,46.97,47,47.2,47.71,46.74,45.73,38.5]
ft_inher = [35.93,40.98,43.62,44.88,45.97,46.85,47.38,46.81,45.73,36.32]
ft_reinit = [37,45.3,47.35,48.34,47.83,49.07,50.05,50.81,50.83,50.91]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

rst_N = [55.38,71.01,74.63,77.41,78.3,75.9,79.7,79.34,77.68,66.4]
ft_inher_N = [60.75,71.37,73.8,75.17,77.42,79.51,79.98,79.58,78.15,70.83]
ft_reinit_N = [61.92,75.54,76.56,76.87,78.57,80.29,80.32,81.81,82.44,81.99]

fig, ax1 = plt.subplots(figsize=(8,4))
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust\ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Natural-RTT@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax2 = ax1.twinx()

# ax2.set_ylabel(r"$\bf{Natural \ Accuracy \ (\%)}$", fontsize = 16)
# ax2.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{Natural-RTT@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{Adv_RTT@Natural}$", lw=lw, linestyle="--")
# ax2.tick_params(axis = 'both', which = 'major', labelsize = 14)

yticks = np.arange(35, 52, 2)
# ax1.set_ylim([34, 83])
ax1.set_yticks(yticks)
# ax1.set_xlim([-0.5,4.5])

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=2, bbox_to_anchor=(1.2, 1.05))
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar10@RST_VS_RTT.svg", dpi=100)

# %%
font_board = 4
lw =3
rst = [37.59,43.96,45.81,46.97,47,47.2,47.71]
ft_inher = [35.93,40.98,43.62,44.88,45.97,46.85,47.38]
ft_reinit = [37,45.3,47.35,48.34,47.83,49.07,50.05]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2]

rst_N = [55.38,71.01,74.63,77.41,78.3,75.9,79.7]
ft_inher_N = [60.75,71.37,73.8,75.17,77.42,79.51,79.98]
ft_reinit_N = [61.92,75.54,76.56,76.87,78.57,80.29,80.32]

fig, ax1 = plt.subplots(figsize=(8,4))
# ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
# ax1.set_ylabel(r"$\bf{Robust\ Accuracy (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 17)

# ax2 = ax1.twinx()

# ax2.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Natural}$", lw=lw, linestyle="--")
# ax2.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax1.set_ylim([35, 50])
xticks = np.arange(0, 0.21, 0.05)
ax1.set_xticks(xticks)
ax1.set_xlim([0, 0.21])
# yticks = np.arange(35, 51, 2)
# ax1.set_ylim([34, 83])
# ax1.set_yticks(yticks)

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=2, bbox_to_anchor=(1.2, 1.05))
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar10@RST_VS_RTT_sub.svg", dpi=100)

# %%
font_board = 1.5
lw = 2
rst = [15.8,22.18,24.66,24.89,26.15,26.21,26.16,25.97,25.03,17.48]
ft_inher = [15.38,20.91,22.49,23.61,24.07,25.14,24.66,23.61,23.06,17.72]
ft_reinit = [14.76,22.91,25.52,25.73,25.78,26.26,26.17,26.76,26.91,26.56]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

# rst_N = [26.24,43.25,48.29,50.14,51.92,52.82,54.83,53.88,51.78,35.35]
# ft_inher_N = [29.14,43.66,48.08,49.22,52.66,55.84,56.81,55,55.27,46.48]
# ft_reinit_N = [26.69,45.41,52.13,54.18,53.03,55.96,56.73,57.19,57.85,58.51]

fig, ax1 = plt.subplots(figsize=(8,4))
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust\ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Natural-RTT@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax2 = ax1.twinx()

# ax2.set_ylabel(r"$\bf{Natural \ Accuracy \ (\%)}$", fontsize = 16)
# ax2.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{Natural-RTT@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{Adv_RTT@Natural}$", lw=lw, linestyle="--")
# ax2.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax1.set_ylim([67, 78])
# ax1.set_xlim([-0.5,4.5])

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=2, bbox_to_anchor=(1.2, 1.05))
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar100@RST_VS_RTT.svg", dpi=100)

# %%
font_board = 4
lw =3
rst = [15.8,22.18,24.66,24.89,26.15,26.21,26.16]
ft_inher = [15.38,20.91,22.49,23.61,24.07,25.14,24.66]
ft_reinit = [14.76,22.91,25.52,25.73,25.78,26.26,26.17]


x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2]

# rst_N = [55.38,68.38,71.01,73.7,74.63,76.09,77.41,76.14,77.58,78.3,75.9,79.7]
# ft_inher_N = [67.92,72.69,75.28,76.93,78.24,79.27,78.83,79.42,80.14,81.08,80.34,81.29]
# ft_reinit_N = [61.6,69.12,71.09,72.45,73.11,74.35,74.79,75.74,75.09,75.46,77.16,78.92]

fig, ax1 = plt.subplots(figsize=(8,4))
# ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
# ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)

# ax1.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Natural}$", lw=lw)

ax1.tick_params(axis = 'both', which = 'major', labelsize = 17)

# ax1.set_ylim([35, 50])
xticks = np.arange(0, 0.21, 0.05)
ax1.set_xticks(xticks)
ax1.set_xlim([0, 0.21])
# yticks = np.arange(35, 51, 2)
# ax1.set_ylim([34, 83])
# ax1.set_yticks(yticks)

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=1)
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("ResNet18@Cifar100@RST_VS_RTT_sub.svg")

# %%
font_board = 1.5
lw = 2
rst = [40.84,46.58,50.06,50.68,51.33,50.71,50.34,49.53,48.26,47.13]
ft_inher = [37.77,48.29,49.3,50.27,49.55,49.61,49.29,48.78,47.63,39.04]
ft_reinit = [48.92,51.73,50.26,50.97,50.93,50.52,51.25,51.13,51.64,51.95]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

# rst_N = [26.24,43.25,48.29,50.14,51.92,52.82,54.83,53.88,51.78,35.35]
# ft_inher_N = [29.14,43.66,48.08,49.22,52.66,55.84,56.81,55,55.27,46.48]
# ft_reinit_N = [26.69,45.41,52.13,54.18,53.03,55.96,56.73,57.19,57.85,58.51]

fig, ax1 = plt.subplots(figsize=(8,4))
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust\ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Natural-RTT@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax2 = ax1.twinx()

# ax2.set_ylabel(r"$\bf{Natural \ Accuracy \ (\%)}$", fontsize = 16)
# ax2.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{Natural-RTT@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{Adv_RTT@Natural}$", lw=lw, linestyle="--")
# ax2.tick_params(axis = 'both', which = 'major', labelsize = 14)

yticks = np.arange(36, 53, 2)
# ax1.set_ylim([34, 83])
ax1.set_yticks(yticks)

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=2, bbox_to_anchor=(1.2, 1.05))
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("WideResNet32@Cifar10@RST_VS_RTT.svg", dpi=100)

# %%
font_board = 4
lw =3
rst = [40.84,46.58,50.06,50.68,51.33,50.71,50.34]
ft_inher = [37.77,48.29,49.3,50.27,49.55,49.61,49.29]
ft_reinit = [48.92,51.73,50.26,50.97,50.93,50.52,51.25]


x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2]

# rst_N = [55.38,68.38,71.01,73.7,74.63,76.09,77.41,76.14,77.58,78.3,75.9,79.7]
# ft_inher_N = [67.92,72.69,75.28,76.93,78.24,79.27,78.83,79.42,80.14,81.08,80.34,81.29]
# ft_reinit_N = [61.6,69.12,71.09,72.45,73.11,74.35,74.79,75.74,75.09,75.46,77.16,78.92]

fig, ax1 = plt.subplots(figsize=(8,4))
# ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
# ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)

# ax1.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Natural}$", lw=lw)

ax1.tick_params(axis = 'both', which = 'major', labelsize = 17)

# ax1.set_ylim([35, 50])
xticks = np.arange(0, 0.21, 0.05)
ax1.set_xticks(xticks)
ax1.set_xlim([0, 0.21])
yticks = np.arange(36, 51, 2)
# ax1.set_ylim([34, 83])
ax1.set_yticks(yticks)

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=1)
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("WideResNet32@Cifar10@RST_VS_RTT_sub.svg")

# %%
font_board = 1.5
lw = 2
rst = [17.44,25.63,26.66,27.68,28.66,28.83,29.17,28.21,27.85,24.18]
ft_inher = [21.96,23.78,25.41,25.43,27.5,27.83,27.12,26.22,25.1,21.25]
ft_reinit = [24.66,27.44,29.34,29.21,29.27,28.87,28.99,29.18,29.15,29.61]

x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2,0.4,0.6,0.8]

# rst_N = [26.24,43.25,48.29,50.14,51.92,52.82,54.83,53.88,51.78,35.35]
# ft_inher_N = [29.14,43.66,48.08,49.22,52.66,55.84,56.81,55,55.27,46.48]
# ft_reinit_N = [26.69,45.41,52.13,54.18,53.03,55.96,56.73,57.19,57.85,58.51]

fig, ax1 = plt.subplots(figsize=(8,4))
ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
ax1.set_ylabel(r"$\bf{Robust\ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{Natural-RTT@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)
ax1.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax2 = ax1.twinx()

# ax2.set_ylabel(r"$\bf{Natural \ Accuracy \ (\%)}$", fontsize = 16)
# ax2.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{Natural-RTT@Natural}$", lw=lw, linestyle="--")
# ax2.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{Adv_RTT@Natural}$", lw=lw, linestyle="--")
# ax2.tick_params(axis = 'both', which = 'major', labelsize = 14)

# ax1.set_ylim([67, 78])
# ax1.set_xlim([-0.5,4.5])

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=2, bbox_to_anchor=(1.2, 1.05))
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("WideResNet32@Cifar100@RST_VS_RTT.svg", dpi=100)

# %%
font_board = 4
lw =3
rst = [17.44,25.63,26.66,27.68,28.66,28.83,29.17]
ft_inher = [21.96,23.78,25.41,25.43,27.5,27.83,27.12]
ft_reinit = [24.66,27.44,29.34,29.21,29.27,28.87,28.99]


x_overall = [0.01,0.03,0.05,0.07,0.1,0.15,0.2]

# rst_N = [55.38,68.38,71.01,73.7,74.63,76.09,77.41,76.14,77.58,78.3,75.9,79.7]
# ft_inher_N = [67.92,72.69,75.28,76.93,78.24,79.27,78.83,79.42,80.14,81.08,80.34,81.29]
# ft_reinit_N = [61.6,69.12,71.09,72.45,73.11,74.35,74.79,75.74,75.09,75.46,77.16,78.92]

fig, ax1 = plt.subplots(figsize=(8,4))
# ax1.set_xlabel(r"$\bf{Remaining \ Ratio}$", fontsize = 16)
# ax1.set_ylabel(r"$\bf{Robust \ Accuracy \ (\%)}$", fontsize = 16)

ax1.plot(x_overall, rst, c='tab:red', marker='s', markersize=3*lw, label=r"$\bf{RST@Robust}$", lw=lw)
ax1.plot(x_overall, ft_inher, c='tab:green', marker='^', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Robust}$", lw=lw)
ax1.plot(x_overall, ft_reinit, c='tab:blue', marker='o', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Robust}$", lw=lw)

# ax1.plot(x_overall, rst_N, c='tab:orange', marker='p', markersize=3*lw, label=r"$\bf{RST@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_inher_N, c='tab:purple', marker='*', markersize=3*lw, label=r"$\bf{FT-RST-Inherit@Natural}$", lw=lw)
# ax1.plot(x_overall, ft_reinit_N, c='tab:gray', marker='D', markersize=3*lw, label=r"$\bf{FT-RST-Reinit@Natural}$", lw=lw)

ax1.tick_params(axis = 'both', which = 'major', labelsize = 17)

# ax1.set_ylim([35, 50])
xticks = np.arange(0, 0.21, 0.05)
ax1.set_xticks(xticks)
ax1.set_xlim([0, 0.21])
# yticks = np.arange(35, 51, 2)
# ax1.set_ylim([34, 83])
# ax1.set_yticks(yticks)

ax1.spines['bottom'].set_linewidth(font_board)
ax1.spines['bottom'].set_color('black')
ax1.spines['left'].set_linewidth(font_board)
ax1.spines['left'].set_color('black')
ax1.spines['top'].set_linewidth(font_board)
ax1.spines['top'].set_color('black')
ax1.spines['right'].set_linewidth(font_board)
ax1.spines['right'].set_color('black')

# leg = ax1.legend(fontsize=font_mid, loc='best', ncol=1)
# leg.get_frame().set_edgecolor("black")
# leg.get_frame().set_linewidth(3)
ax1.grid(axis='both', color='gray', linestyle='-', linewidth=0.3)


fig.tight_layout()  # otherwise the right y-label is slightly clipped
# ax1.grid(True)
plt.savefig("WideResNet32@Cifar100@RST_VS_RTT_sub.svg")
